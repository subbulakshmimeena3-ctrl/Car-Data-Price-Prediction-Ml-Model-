# %%
# !pip install numpy
# Out:
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      ------------- ------------------------- 20.5/60.9 kB 73.1 kB/s eta 0:00:01
#      ------------- ------------------------- 20.5/60.9 kB 73.1 kB/s eta 0:00:01
#      ------------------- ------------------ 30.7/60.9 kB 100.9 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.9 kB 122.9 kB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 162.3 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/13.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/13.0 MB 1.7 MB/s eta 0:00:08
# ...

# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.3.1'

# %%
arr = np.array([1,2,3,4,5])
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
l = [1,2,3,4,5]

# %%
type(1)
# Out:
# int

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
#list vs numpy

# %%
l = [1, 1.5,"Mohit"]

# %%
l
# Out:
# [1, 1.5, 'Mohit']

# %%
arr = np.array([1,1.5,12,34,'mohit'])
arr
# Out:
# array(['1', '1.5', '12', '34', 'mohit'], dtype='<U32')

# %%
arr.dtype
# Out:
# dtype('<U32')

# %%
arr.ndim
# Out:
# 1

# %%
arr.size
# Out:
# 5

# %%
arr = np.array([1,2,3,4,5])
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr = np.array
