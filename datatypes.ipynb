# %%
1+3
# Out:
# 4

# %%
num = int(input("Enter a number: "))
print("Even" if num % 2 == 0 else "Odd")
# Out:
# Odd

# %%
ch = input("Enter a letter: ").lower()
print("Vowel" if ch in "aeiou" else "Consonant")
# Out:
# Consonant

# %%
temp = float(input("Temperature in °C: "))
print("Cold" if temp < 10 else "Pleasant" if temp <= 25 else "Hot")
# Out:
# Cold

# %%
marks = int(input("Marks: "))
if 90 <= marks <= 100:
    print("A")
elif 75 <= marks <= 89:
    print("B")
elif 50 <= marks <= 74:
    print("C")
else:
    print("F")
# Out:
# B

# %%
num = int(input("Enter a 3-digit number: "))
digits = [int(d) for d in str(num)]
print("Armstrong" if sum(d**3 for d in digits) == num else "Not Armstrong")
# Out:
# Not Armstrong

# %%
balance = 5000
amount = int(input("Amount: "))
if amount % 100 == 0 and amount <= balance:
    print("Withdrawn", amount)
else:
    print("Can't withdraw")
# Out:
# Can't withdraw

# %%
a = float(input("First number: "))
b = float(input("Second number: "))
op = input("Operator (+, -, *, /): ")

if op == '+':
    print(a + b)
elif op == '-':
    print(a - b)
elif op == '*':
    print(a * b)
elif op == '/':
    if b != 0:
        print(a / b)
    else:
        print("Cannot divide by zero")
else:
    print("Invalid operator")
# Out:
# Invalid operator

# %%
age = int(input("Age: "))
print("child" if age < 13 else "teen" if age <= 19 else "adult")
# Out:
# adult

# %%
a = int(input("First number: "))
b = int(input("Second number: "))
print("Largest:", a if a > b else b)
# Out:
# Largest: 45

# %%
a = int(input("First: "))
b = int(input("Second: "))
c = int(input("Third: "))
print("Largest:", max(a, b, c))
# Out:
# Largest: 6

# %%
year = int(input("Year: "))
print("Leap year" if year % 4 == 0 and (year % 100 != 0 or year % 400 == 0) else "Not a leap year")
# Out:
# Not a leap year

# %%
n = int(input("Enter a number: "))
if n % 3 == 0 and n % 5 == 0:
    print("Divisible by both 3 and 5")
elif n % 3 == 0:
    print("Divisible by 3 only")
elif n % 5 == 0:
    print("Divisible by 5 only")
else:
    print("Not divisible by 3 or 5")
# Out:
# Divisible by 3 only

# %%
print("hello world")
# Out:
# hello world
