# %%
class Person:
    def setname(self,apple):
        self.name = apple
    def getname(self):
        return self.name

# %%
p = Person()

# %%
p.getname()

# %%
#WAP to make a bank_atm_simulation system
#create a constructor which takes acc_np, name, balance as args
#create a functionality which returns all the details 
#create a fucnctionality to deposit the amount in bank in such a way thatdeposited amount must be 100 or more and must be in multiple of 100 
#create a fucntionality to withdraw amount from bank in such a way that withdrawl amount must be 100 or more and must be in multiple of 100 
#create a passbook of transactions happend from first till the last => acc_no,credit,debit,currentbalance

# %%
print("hipoocampus")
# Out:
# hipoocampus

# %%
class Bank_ATM:
    def __init__(self,acc_no,name,balance):
        self.acc_no = acc_no 
        self.name = name
        self.balance = balance
        self.transaction = [(acc_no, balance,0,balance)] # to store transcation history 

    def get_detaills(self):
        return self.acc_no,self.name,self.balance 
    def deposit(self,amount):
        if amount>=100 and amount%100 ==0
         self.balance += amount self.transactions.append((self.acc_no,amount,0,self.balance))
         print("transaction successful")
         print(f"your amount of Rs.{amount} has ben deposited into bank")
        else:
           print("Transaction Failed")
           print("Minimum deposited amount must be 100 or more and must be multipled of 100")

    def withdrawal (self,amount)

# %%
#inheritance
class Parent:
    def m1(self):
        return "Parent Class"
class Child(Parent):
    def m2(self):
        return "Child method"

# %%
#multilevel 
class GrandParent:
    def m1(self):
        return "Grand Parent method"
class Parent:
    def m2(self):
        return "Parent method"

class Child(Parent):
    def m3(self):
        return"Child method"

# %%
c.m3
# Out:
# <function __main__.Child.m3(self)>

# %%
c = Child

# %%
#Hierarical
class Parent:
    def m1(self):
        return "Parent method"
class Child1(Parent):
    def m2(self):
        return "Parent method"

class Chil2(Parent):
    def m3(self):
        return"Child method"

# %%
c1.m3()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 c1.m3()
#
# NameError: name 'c1' is not defined

# %%
c2 = Child()

# %%
c2.m3()
# Out:
# 'Child method'

# %%
c2.m2()
# Out:
# 'Parent method'

# %%
# multiple 
class Parent1:
    def m1(self):
        return "Parent1 method"
class Parent2:
        def m1(self):
            return "Parent2 method"
class Child(Parent1, Parent2):
    def m3(self):
        return "child method"

# %%
# hybrid 
class Parent1:
    def m1(self):
        return "Parent1 method"
class Parent2:
        def m1(self):
            return "Parent2 method"
class Child(Parent1, Parent2):
    def m3(self):
        return "child method"
class SubChild(Child):
     def m4(self):
          return "subChild method"

# %%
sc = Child()

# %%
sc.m3()
# Out:
# 'child method'

# %%
# Enscapsulation
class bank:
    def __init__ (sel, acc_no, name, balance):
        self. __name = name
        self. __acc_no = acc_no
        self. __balance = balance

# %%
bank.balance
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 bank.balance
#
# AttributeError: type object 'bank' has no attribute 'balance'
